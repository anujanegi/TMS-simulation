# %%
import imageio
import scipy.ndimage as ndi
import scipy.stats
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

# %%
from nilearn import image as nimg
from nilearn import plotting as nplot

# %%
t1 = './data/ADNI/002_S_0938/MP-RAGE/2007-10-23_09_18_05.0/S41834/ADNI_002_S_0938_MR_MP-RAGE__br_raw_20071023201953126_166_S41834_I78379.nii'
t2 = './data/ADNI/002_S_0938/Axial_PD_T2_FSE/2007-10-23_09_37_02.0/S41833/ADNI_002_S_0938_MR_Axial_PD_T2_FSE__br_raw_20071023202139009_96_S41833_I78381.nii'
t1_img = nimg.load_img(t1)
t2_img = nimg.load_img(t2)

# %%
nplot.plot_anat(t1_img)
nplot.plot_anat(t2_img)

# %%
ef = 'data/electric_fields/ernie FC6/mni_volumes/ernie_TMS_1-0001_Magstim_70mm_Fig8_nii_scalar_MNI_normE.nii.gz'
ef_img = nimg.load_img(ef)
nplot.plot_anat(ef_img)

# %%
nplot.view_img(ef_img,
               bg_img=False, # Disable using a standard image as the background
               cmap='plasma', # Set color scale so white matter appears lighter than grey
               symmetric_cmap=False, # We don't have negative values
               threshold="auto", # Clears out the background
              )
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagittal) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;background&quot; /&gt;
#     &lt;!-- the colormap --&gt;
#     &lt;img id=&quot;colorMap&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;colormap&quot;&gt;
#     &lt;!-- another sprite image, with an overlay--&gt;
#     &lt;img id=&quot;overlayImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;overlay&quot;&gt;
# ...

# %%
nplot.view_img(t2_img,
               bg_img=False, # Disable using a standard image as the background
            #    cmap='Greys_r', # Set color scale so white matter appears lighter than grey
               symmetric_cmap=False, # We don't have negative values
               threshold="auto", # Clears out the background
              )
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagittal) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;background&quot; /&gt;
#     &lt;!-- the colormap --&gt;
#     &lt;img id=&quot;colorMap&quot; class=&quot;hidden&quot; src=&quot;...&quot; alt=&quot;colormap&quot;&gt;
#     &lt;!-- another sprite image, with an overlay--&gt;
#     &lt;img id=&quot;overlayImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;overlay&quot;&gt;
#     &lt;/canvas&gt;
#   &lt;/div&gt;
#
# ...

# %%
from nilearn import datasets
from nilearn import plotting
from nilearn.image import index_img
adhd = datasets.fetch_adhd(n_subjects=1)
func = adhd.func[0]

volume = index_img(func, 0)
plotting.plot_glass_brain(volume)
plotting.show()
# Out:
# ...
# Downloaded 3842048 of 44414948 bytes (8.7%,  2.4min remaining)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_9833/1438137376.py in <module>
#       2 from nilearn import plotting
#       3 from nilearn.image import index_img
# ----> 4 adhd = datasets.fetch_adhd(n_subjects=1)
#       5 func = adhd.func[0]
#       6
#
# ~/anaconda3/envs/tvb_simnibs/lib/python3.7/site-packages/nilearn/datasets/func.py in fetch_adhd(n_subjects, data_dir, url, resume, verbose)
#     266     functionals = _fetch_files(
#     267         data_dir, zip(functionals, archives, (opts,) * n_subjects),
# --> 268         resume=resume, verbose=verbose)
#     269
#     270     confounds = _fetch_files(
#
# ~/anaconda3/envs/tvb_simnibs/lib/python3.7/site-packages/nilearn/datasets/utils.py in _fetch_files(data_dir, files, resume, verbose, session)
#     711             return _fetch_files(
# ...

# %%
import nibabel as nb
data = nb.load('./data/ADNI/941_S_6854/Sagittal_3D_FLAIR/FLAIR.nii').get_fdata()

# %%
data.shape
# Out:
# (160, 256, 256)

# %%
data.shape
# Out:
# (208, 240, 256)

# %%
img = nb.load('data/ADNI/941_S_6854/Accelerated_Sagittal_MPRAGE/2022-02-22_13_04_08.0/S1107461/ADNI_941_S_6854_MR_Accelerated_Sagittal_MPRAGE__br_raw_20220223103920549_66_S1107461_I1547737.nii')
type(img)
data = img.get_fdata()

empty_header = nib.Nifti1Header()
another_img = nib.Nifti1Image(data[:,:,:,0], img.affine, empty_header)
nib.save(another_img, './data/ADNI/941_S_6854/Accelerated_Sagittal_MPRAGE/T1.nii')

# %%
img = nb.load('data/ADNI/941_S_6854/Sagittal_3D_FLAIR/2022-02-22_13_04_08.0/S1107466/ADNI_941_S_6854_MR_Sagittal_3D_FLAIR__br_raw_20220223103920089_82_S1107466_I1547745.nii')
type(img)
data = img.get_fdata()

empty_header = nib.Nifti1Header()
another_img = nib.Nifti1Image(data[:,:,:,0], img.affine, empty_header)
nib.save(another_img, './data/ADNI/941_S_6854/Sagittal_3D_FLAIR/FLAIR.nii')
